# %% [markdown]
# <a href="https://colab.research.google.com/github/moon2su/ML-programming/blob/main/HAR_Transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns

def load_file(filepath):
    dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
    return dataframe.values

# load a list of files and return as a 3d numpy array
def load_group(filenames, prefix=''):
    loaded = list()
    for name in filenames:
        data = load_file(prefix + name)
        loaded.append(data)
    # stack group so that features are the 3rd dimension
    loaded = np.dstack(loaded)
    return loaded

# load a dataset group, such as train or test
def load_dataset_group(group, prefix=''):
    filepath = prefix + group + '/Inertial Signals/'
    # load all 9 files as a single array
    filenames = list()
    # total acceleration
    filenames += ['total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt']
    # body acceleration
    filenames += ['body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt']
    # body gyroscope
    filenames += ['body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt']
    # load input data
    X = load_group(filenames, filepath)
    # load class output
    y = load_file(prefix + group + '/y_'+group+'.txt')
    return X, y


# load the dataset, returns train and test X and y elements
def load_dataset(prefix=''):
    # load all train
    trainX, trainy = load_dataset_group('train', prefix + '/content/drive/MyDrive/Colab Notebooks/human+activity+recognition+using+smartphones/UCI HAR Dataset/UCI HAR Dataset/')
    # load all test
    testX, testy = load_dataset_group('test', prefix + '/content/drive/MyDrive/Colab Notebooks/human+activity+recognition+using+smartphones/UCI HAR Dataset/UCI HAR Dataset/')

    #zero-offset class values
    trainy = trainy - 1
    testy = testy - 1
    #one hot encode y
    trainy_one_hot = to_categorical(trainy)
    testy_one_hot = to_categorical(testy)
    print(trainX.shape, trainy.shape, trainy_one_hot.shape, testX.shape, testy.shape, testy_one_hot.shape)
    return trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot

trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot = load_dataset()

from sklearn.model_selection import train_test_split

X_train,X_val,y_train_one_hot,y_val_one_hot,y_train,y_val=train_test_split(trainX, trainy_one_hot, trainy,test_size=0.2,random_state=100)

from sklearn.preprocessing import StandardScaler

# ---------- 데이터 스케일링 함수 ----------
def scale_3d_timeseries(X_train, X_val, X_test=None):
    """
    3D 시계열 (N, T, F) 형태의 데이터를 feature-wise로 표준화
    """
    N, T, F = X_train.shape
    scaler = StandardScaler()

    scaler.fit(X_train.reshape(-1, F))

    def transform_3d(X):
        if X is None:
            return None
        N_, T_, F_ = X.shape
        X2 = X.reshape(-1, F_)
        X2 = scaler.transform(X2)
        return X2.reshape(N_, T_, F_)

    X_train_scaled = transform_3d(X_train)
    X_val_scaled = transform_3d(X_val)
    X_test_scaled = transform_3d(X_test)

    return X_train_scaled, X_val_scaled, X_test_scaled, scaler

# ---------- 실행 ----------
X_train_scaled, X_val_scaled, X_test_scaled, scaler = scale_3d_timeseries(X_train, X_val, testX)

# 스케일링 후 shape 확인
print("Scaled shapes:")
print("X_train_scaled:", X_train_scaled.shape)
print("X_val_scaled:", X_val_scaled.shape)
print("X_test_scaled:", X_test_scaled.shape)
print("-------------------")

X_train.shape,X_val.shape,y_train_one_hot.shape,y_val_one_hot.shape,y_train.shape,y_val.shape
# Out:
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# (7352, 128, 9) (7352, 1) (7352, 6) (2947, 128, 9) (2947, 1) (2947, 6)
# Scaled shapes:
# X_train_scaled: (5881, 128, 9)
# X_val_scaled: (1471, 128, 9)
# X_test_scaled: (2947, 128, 9)
# -------------------
# ((5881, 128, 9), (1471, 128, 9), (5881, 6), (1471, 6), (5881, 1), (1471, 1))

# %%
n_timesteps, n_features, n_outputs = X_train.shape[1], X_train.shape[2], y_train_one_hot.shape[1]

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Dense, Dropout, GaussianNoise,
    MultiHeadAttention, LayerNormalization,
    GlobalAveragePooling1D, Embedding
)

# 앞에서 이미 정의된 값 그대로 사용:
# n_timesteps, n_features, n_outputs = X_train.shape[1], X_train.shape[2], y_train_one_hot.shape[1]

# --------------------------
# Transformer Encoder 블록
# --------------------------
def transformer_encoder(x, num_heads, d_model, ff_dim, dropout=0.1):
    """
    x: (batch, time, d_model)
    num_heads: multi-head attention head 수
    d_model: 모델 차원
    ff_dim: FFN 은닉층 차원
    """

    # num_heads * key_dim == d_model 이 되도록 설정
    key_dim = d_model // num_heads

    # 1) Multi-Head Self-Attention + 잔차연결 + LayerNorm
    attn_output = MultiHeadAttention(
        num_heads=num_heads,
        key_dim=key_dim
    )(x, x)  # self-attention이므로 (query, key) 둘 다 x
    attn_output = Dropout(dropout)(attn_output)
    out1 = LayerNormalization(epsilon=1e-6)(x + attn_output)

    # 2) Position-wise FFN + 잔차연결 + LayerNorm
    ffn = Dense(ff_dim, activation='relu')(out1)
    ffn = Dropout(dropout)(ffn)
    ffn = Dense(d_model)(ffn)
    out2 = LayerNormalization(epsilon=1e-6)(out1 + ffn)

    return out2

# --------------------------
# 입력 & 포지셔널 임베딩
# --------------------------
inputs = Input(shape=(n_timesteps, n_features))

# 약간의 노이즈로 일반화 성능 향상
x = GaussianNoise(0.01)(inputs)

# 연속형 feature를 d_model 차원으로 projection
d_model = 64
x = Dense(d_model)(x)   # (batch, time, d_model)

# 간단한 learnable positional embedding
positions = tf.range(start=0, limit=n_timesteps, delta=1)
pos_embedding_layer = Embedding(input_dim=n_timesteps, output_dim=d_model)
pos_embed = pos_embedding_layer(positions)           # (time, d_model)
x = x + pos_embed                                   # broadcasting: (batch, time, d_model) + (time, d_model)

# --------------------------
# Transformer Encoder 스택
# --------------------------
num_heads = 4
ff_dim = 128
num_layers = 2   # encoder 블록 2개

for _ in range(num_layers):
    x = transformer_encoder(x, num_heads=num_heads, d_model=d_model, ff_dim=ff_dim, dropout=0.1)

# --------------------------
# 풀링 + 분류기
# --------------------------
x = GlobalAveragePooling1D()(x)   # (batch, d_model)

x = Dense(128, activation='relu')(x)
x = Dropout(0.4)(x)

outputs = Dense(n_outputs, activation='softmax')(x)

transformer_model = Model(inputs=inputs, outputs=outputs, name="transformer_har")

# Label Smoothing 그대로 사용
loss = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.05)
opt  = tf.keras.optimizers.Adam(learning_rate=1e-3)

transformer_model.compile(loss=loss, optimizer=opt, metrics=['accuracy'])
transformer_model.summary()
# Out:
# Model: "transformer_har"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 9)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gaussian_noise      │ (None, 128, 9)    │          0 │ input_layer[0][0] │
# │ (GaussianNoise)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128, 64)   │        640 │ gaussian_noise[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 128, 64)   │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 128, 64)   │     16,640 │ add[0][0],        │
# │ (MultiHeadAttentio… │                   │            │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128, 64)   │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 128, 64)   │          0 │ add[0][0],        │
# │                     │                   │            │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 128, 64)   │        128 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 128, 128)  │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 128, 128)  │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 128, 64)   │      8,256 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 128, 64)   │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 128, 64)   │        128 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 128, 64)   │     16,640 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 128, 64)   │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 128, 64)   │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 128, 64)   │        128 │ add_3[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 128, 128)  │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 128, 128)  │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 128, 64)   │      8,256 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 128, 64)   │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 128, 64)   │        128 │ add_4[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ layer_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 128)       │      8,320 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 128)       │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 6)         │        774 │ dropout_6[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 76,678 (299.52 KB)
#  Trainable params: 76,678 (299.52 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from sklearn.metrics import f1_score
from tensorflow.keras.callbacks import Callback

class F1MacroCallback(Callback):
    def __init__(self, X_val, y_val, batch_size=256):
        super().__init__()
        self.X_val = X_val
        self.y_val = y_val
        self.bs = batch_size

    def on_epoch_end(self, epoch, logs=None):
        y_prob = self.model.predict(self.X_val, batch_size=self.bs, verbose=0)
        y_pred = y_prob.argmax(axis=1)
        y_true = self.y_val.argmax(axis=1)
        f1m = f1_score(y_true, y_pred, average='macro')
        logs = logs or {}
        logs['val_f1_macro'] = f1m
        print(f"\nval_f1_macro: {f1m:.4f}")

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

f1_cb = F1MacroCallback(X_val_scaled, y_val_one_hot, batch_size=256)

callbacks = [
    f1_cb,
    EarlyStopping(monitor='val_f1_macro', mode='max', patience=12, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_f1_macro', mode='max', factor=0.5, patience=5, min_lr=1e-5, verbose=1),
    # ModelCheckpoint('best_simple_cnn_f1.keras', monitor='val_f1_macro', mode='max', save_best_only=True, verbose=1)
]

# %%
model_history = transformer_model.fit(
    X_train_scaled, y_train_one_hot,
    validation_data=(X_val_scaled, y_val_one_hot),
    epochs=30,
    batch_size=128,
    callbacks=callbacks + [f1_cb],
)
# Out:
# Epoch 1/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.5676 - loss: 1.1920
# val_f1_macro: 0.8571
#
# val_f1_macro: 0.8571
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 36s 290ms/step - accuracy: 0.5707 - loss: 1.1855 - val_accuracy: 0.8668 - val_loss: 0.5654 - val_f1_macro: 0.8571 - learning_rate: 0.0010
# Epoch 2/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9024 - loss: 0.5272
# val_f1_macro: 0.9313
#
# val_f1_macro: 0.9313
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9030 - loss: 0.5250 - val_accuracy: 0.9300 - val_loss: 0.3882 - val_f1_macro: 0.9313 - learning_rate: 0.0010
# Epoch 3/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9408 - loss: 0.3976
# val_f1_macro: 0.9492
#
# val_f1_macro: 0.9492
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9410 - loss: 0.3973 - val_accuracy: 0.9470 - val_loss: 0.3658 - val_f1_macro: 0.9492 - learning_rate: 0.0010
# Epoch 4/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9529 - loss: 0.3710
# val_f1_macro: 0.9498
#
# val_f1_macro: 0.9498
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9528 - loss: 0.3711 - val_accuracy: 0.9470 - val_loss: 0.3555 - val_f1_macro: 0.9498 - learning_rate: 0.0010
# Epoch 5/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9493 - loss: 0.3650
# val_f1_macro: 0.9531
#
# val_f1_macro: 0.9531
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9495 - loss: 0.3649 - val_accuracy: 0.9497 - val_loss: 0.3488 - val_f1_macro: 0.9531 - learning_rate: 0.0010
# Epoch 6/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9504 - loss: 0.3665
# val_f1_macro: 0.9517
#
# val_f1_macro: 0.9517
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9504 - loss: 0.3663 - val_accuracy: 0.9483 - val_loss: 0.3402 - val_f1_macro: 0.9517 - learning_rate: 0.0010
# Epoch 7/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9594 - loss: 0.3476
# val_f1_macro: 0.9540
#
# val_f1_macro: 0.9540
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9593 - loss: 0.3478 - val_accuracy: 0.9511 - val_loss: 0.3406 - val_f1_macro: 0.9540 - learning_rate: 0.0010
# Epoch 8/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9623 - loss: 0.3436
# val_f1_macro: 0.9530
#
# val_f1_macro: 0.9530
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9621 - loss: 0.3438 - val_accuracy: 0.9497 - val_loss: 0.3366 - val_f1_macro: 0.9530 - learning_rate: 0.0010
# Epoch 9/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9573 - loss: 0.3474
# val_f1_macro: 0.9588
#
# val_f1_macro: 0.9588
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9574 - loss: 0.3472 - val_accuracy: 0.9558 - val_loss: 0.3349 - val_f1_macro: 0.9588 - learning_rate: 0.0010
# Epoch 10/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9540 - loss: 0.3502
# val_f1_macro: 0.9567
#
# val_f1_macro: 0.9567
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9541 - loss: 0.3499 - val_accuracy: 0.9538 - val_loss: 0.3329 - val_f1_macro: 0.9567 - learning_rate: 0.0010
# Epoch 11/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9650 - loss: 0.3322
# val_f1_macro: 0.9528
#
# val_f1_macro: 0.9528
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9648 - loss: 0.3325 - val_accuracy: 0.9504 - val_loss: 0.3355 - val_f1_macro: 0.9528 - learning_rate: 0.0010
# Epoch 12/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9650 - loss: 0.3359
# val_f1_macro: 0.9589
#
# val_f1_macro: 0.9589
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9648 - loss: 0.3359 - val_accuracy: 0.9565 - val_loss: 0.3275 - val_f1_macro: 0.9589 - learning_rate: 0.0010
# Epoch 13/30
# 44/46 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9573 - loss: 0.3326
# val_f1_macro: 0.9651
#
# val_f1_macro: 0.9651
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9576 - loss: 0.3325 - val_accuracy: 0.9626 - val_loss: 0.3202 - val_f1_macro: 0.9651 - learning_rate: 0.0010
# Epoch 14/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9687 - loss: 0.3243
# val_f1_macro: 0.9725
#
# val_f1_macro: 0.9725
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9687 - loss: 0.3241 - val_accuracy: 0.9708 - val_loss: 0.3057 - val_f1_macro: 0.9725 - learning_rate: 0.0010
# Epoch 15/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9745 - loss: 0.3137
# val_f1_macro: 0.9740
#
# val_f1_macro: 0.9740
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9743 - loss: 0.3138 - val_accuracy: 0.9728 - val_loss: 0.3023 - val_f1_macro: 0.9740 - learning_rate: 0.0010
# Epoch 16/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9732 - loss: 0.3153
# val_f1_macro: 0.9763
#
# val_f1_macro: 0.9763
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9732 - loss: 0.3153 - val_accuracy: 0.9748 - val_loss: 0.3071 - val_f1_macro: 0.9763 - learning_rate: 0.0010
# Epoch 17/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9725 - loss: 0.3138
# val_f1_macro: 0.9748
#
# val_f1_macro: 0.9748
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9725 - loss: 0.3138 - val_accuracy: 0.9735 - val_loss: 0.2986 - val_f1_macro: 0.9748 - learning_rate: 0.0010
# Epoch 18/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9775 - loss: 0.3047
# val_f1_macro: 0.9805
#
# val_f1_macro: 0.9805
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9775 - loss: 0.3048 - val_accuracy: 0.9796 - val_loss: 0.2923 - val_f1_macro: 0.9805 - learning_rate: 0.0010
# Epoch 19/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9789 - loss: 0.3049
# val_f1_macro: 0.9726
#
# val_f1_macro: 0.9726
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9790 - loss: 0.3048 - val_accuracy: 0.9714 - val_loss: 0.3087 - val_f1_macro: 0.9726 - learning_rate: 0.0010
# Epoch 20/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9763 - loss: 0.3050
# val_f1_macro: 0.9755
#
# val_f1_macro: 0.9755
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9764 - loss: 0.3049 - val_accuracy: 0.9742 - val_loss: 0.3074 - val_f1_macro: 0.9755 - learning_rate: 0.0010
# Epoch 21/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9787 - loss: 0.3027
# val_f1_macro: 0.9782
#
# val_f1_macro: 0.9782
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9788 - loss: 0.3026 - val_accuracy: 0.9769 - val_loss: 0.2970 - val_f1_macro: 0.9782 - learning_rate: 0.0010
# Epoch 22/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9835 - loss: 0.2938
# val_f1_macro: 0.9851
#
# val_f1_macro: 0.9851
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9836 - loss: 0.2937 - val_accuracy: 0.9844 - val_loss: 0.2786 - val_f1_macro: 0.9851 - learning_rate: 0.0010
# Epoch 23/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9865 - loss: 0.2869
# val_f1_macro: 0.9844
#
# val_f1_macro: 0.9844
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9864 - loss: 0.2869 - val_accuracy: 0.9837 - val_loss: 0.2883 - val_f1_macro: 0.9844 - learning_rate: 0.0010
# Epoch 24/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9844 - loss: 0.2877
# val_f1_macro: 0.9864
#
# val_f1_macro: 0.9864
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9845 - loss: 0.2876 - val_accuracy: 0.9857 - val_loss: 0.2816 - val_f1_macro: 0.9864 - learning_rate: 0.0010
# Epoch 25/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9878 - loss: 0.2835
# val_f1_macro: 0.9845
#
# val_f1_macro: 0.9845
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9878 - loss: 0.2836 - val_accuracy: 0.9837 - val_loss: 0.2806 - val_f1_macro: 0.9845 - learning_rate: 0.0010
# Epoch 26/30
# 44/46 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9870 - loss: 0.2849
# val_f1_macro: 0.9858
#
# val_f1_macro: 0.9858
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9870 - loss: 0.2848 - val_accuracy: 0.9850 - val_loss: 0.2779 - val_f1_macro: 0.9858 - learning_rate: 0.0010
# Epoch 27/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9919 - loss: 0.2768
# val_f1_macro: 0.9845
#
# val_f1_macro: 0.9845
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9917 - loss: 0.2772 - val_accuracy: 0.9837 - val_loss: 0.2846 - val_f1_macro: 0.9845 - learning_rate: 0.0010
# Epoch 28/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9817 - loss: 0.2904
# val_f1_macro: 0.9854
#
# val_f1_macro: 0.9854
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9818 - loss: 0.2904 - val_accuracy: 0.9844 - val_loss: 0.2876 - val_f1_macro: 0.9854 - learning_rate: 0.0010
# Epoch 29/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9892 - loss: 0.2813
# val_f1_macro: 0.9841
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# val_f1_macro: 0.9841
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9892 - loss: 0.2813 - val_accuracy: 0.9830 - val_loss: 0.2844 - val_f1_macro: 0.9841 - learning_rate: 0.0010
# Epoch 30/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9917 - loss: 0.2714
# val_f1_macro: 0.9898
#
# val_f1_macro: 0.9898
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9918 - loss: 0.2714 - val_accuracy: 0.9891 - val_loss: 0.2745 - val_f1_macro: 0.9898 - learning_rate: 5.0000e-04

# %%
import matplotlib.pyplot as plt
import seaborn as sns

loss =model_history.history['loss']
val_loss =model_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc =model_history.history['accuracy']
val_acc =model_history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, f1_score, classification_report
import numpy as np

# 예측
y_val_prob = transformer_model.predict(X_val_scaled, batch_size=256)
y_val_pred = y_val_prob.argmax(axis=1)
y_val_true = y_val_one_hot.argmax(axis=1)

# 혼동행렬
cm = confusion_matrix(y_val_true, y_val_pred)
f1_macro = f1_score(y_val_true, y_val_pred, average='macro')
f1_micro = f1_score(y_val_true, y_val_pred, average='micro')

# 결과 출력
print(f"Validation macro F1: {f1_macro:.4f}")
print(f"Validation micro F1: {f1_micro:.4f}")
print(classification_report(y_val_true, y_val_pred))

# -----------------------------
# 🔥 히트맵 시각화
# -----------------------------
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=True,
            xticklabels=np.unique(y_val_true),
            yticklabels=np.unique(y_val_true))
plt.title(f'Confusion Matrix (F1_macro={f1_macro:.3f})')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Validation macro F1: 0.9898
# Validation micro F1: 0.9891
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       243
#            1       1.00      1.00      1.00       203
#            2       1.00      1.00      1.00       207
#            3       0.95      0.99      0.97       246
#            4       0.99      0.95      0.97       281
#            5       1.00      1.00      1.00       291
#
#     accuracy                           0.99      1471
#    macro avg       0.99      0.99      0.99      1471
# weighted avg       0.99      0.99      0.99      1471
