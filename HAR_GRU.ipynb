# %% [markdown]
# <a href="https://colab.research.google.com/github/moon2su/ML-programming/blob/main/HAR_GRU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns

def load_file(filepath):
    dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
    return dataframe.values

# load a list of files and return as a 3d numpy array
def load_group(filenames, prefix=''):
    loaded = list()
    for name in filenames:
        data = load_file(prefix + name)
        loaded.append(data)
    # stack group so that features are the 3rd dimension
    loaded = np.dstack(loaded)
    return loaded

# load a dataset group, such as train or test
def load_dataset_group(group, prefix=''):
    filepath = prefix + group + '/Inertial Signals/'
    # load all 9 files as a single array
    filenames = list()
    # total acceleration
    filenames += ['total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt']
    # body acceleration
    filenames += ['body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt']
    # body gyroscope
    filenames += ['body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt']
    # load input data
    X = load_group(filenames, filepath)
    # load class output
    y = load_file(prefix + group + '/y_'+group+'.txt')
    return X, y


# load the dataset, returns train and test X and y elements
def load_dataset(prefix=''):
    # load all train
    trainX, trainy = load_dataset_group('train', prefix + '/content/drive/MyDrive/Colab Notebooks/human+activity+recognition+using+smartphones/UCI HAR Dataset/UCI HAR Dataset/')
    # load all test
    testX, testy = load_dataset_group('test', prefix + '/content/drive/MyDrive/Colab Notebooks/human+activity+recognition+using+smartphones/UCI HAR Dataset/UCI HAR Dataset/')

    #zero-offset class values
    trainy = trainy - 1
    testy = testy - 1
    #one hot encode y
    trainy_one_hot = to_categorical(trainy)
    testy_one_hot = to_categorical(testy)
    print(trainX.shape, trainy.shape, trainy_one_hot.shape, testX.shape, testy.shape, testy_one_hot.shape)
    return trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot

trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot = load_dataset()

from sklearn.model_selection import train_test_split

X_train,X_val,y_train_one_hot,y_val_one_hot,y_train,y_val=train_test_split(trainX, trainy_one_hot, trainy,test_size=0.2,random_state=100)

from sklearn.preprocessing import StandardScaler

# ---------- 데이터 스케일링 함수 ----------
def scale_3d_timeseries(X_train, X_val, X_test=None):
    """
    3D 시계열 (N, T, F) 형태의 데이터를 feature-wise로 표준화
    """
    N, T, F = X_train.shape
    scaler = StandardScaler()

    scaler.fit(X_train.reshape(-1, F))

    def transform_3d(X):
        if X is None:
            return None
        N_, T_, F_ = X.shape
        X2 = X.reshape(-1, F_)
        X2 = scaler.transform(X2)
        return X2.reshape(N_, T_, F_)

    X_train_scaled = transform_3d(X_train)
    X_val_scaled = transform_3d(X_val)
    X_test_scaled = transform_3d(X_test)

    return X_train_scaled, X_val_scaled, X_test_scaled, scaler

# ---------- 실행 ----------
X_train_scaled, X_val_scaled, X_test_scaled, scaler = scale_3d_timeseries(X_train, X_val, testX)

# 스케일링 후 shape 확인
print("Scaled shapes:")
print("X_train_scaled:", X_train_scaled.shape)
print("X_val_scaled:", X_val_scaled.shape)
print("X_test_scaled:", X_test_scaled.shape)
print("-------------------")

X_train.shape,X_val.shape,y_train_one_hot.shape,y_val_one_hot.shape,y_train.shape,y_val.shape
# Out:
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-2086117023.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# (7352, 128, 9) (7352, 1) (7352, 6) (2947, 128, 9) (2947, 1) (2947, 6)
# Scaled shapes:
# X_train_scaled: (5881, 128, 9)
# X_val_scaled: (1471, 128, 9)
# X_test_scaled: (2947, 128, 9)
# -------------------
# ((5881, 128, 9), (1471, 128, 9), (5881, 6), (1471, 6), (5881, 1), (1471, 1))

# %%
n_timesteps, n_features, n_outputs = X_train.shape[1], X_train.shape[2], y_train_one_hot.shape[1]

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Input, GRU, Bidirectional,
    Dense, Dropout, GaussianNoise
)

# n_timesteps, n_features, n_outputs 는 이전 셀에서 이미 정의됨
gru = Sequential([
    Input(shape=(n_timesteps, n_features)),

    # 약간의 노이즈로 일반화 성능 향상
    GaussianNoise(0.01),

    # 첫 번째 Bi-GRU 블록 (시퀀스 전체 출력 유지)
    Bidirectional(
        GRU(128, return_sequences=True)
    ),
    Dropout(0.3),

    # 두 번째 Bi-GRU 블록 (마지막 타임스텝 출력만 사용)
    Bidirectional(
        GRU(64, return_sequences=False)
    ),
    Dropout(0.3),

    # 완전연결층
    Dense(128, activation='relu'),
    Dropout(0.4),

    # 최종 클래스 출력층
    Dense(n_outputs, activation='softmax')
])

# Label Smoothing 그대로 사용
loss = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.05)
opt  = tf.keras.optimizers.Adam(learning_rate=1e-3)

gru.compile(loss=loss, optimizer=opt, metrics=['accuracy'])
gru.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gaussian_noise (GaussianNoise)  │ (None, 128, 9)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 128, 256)       │       106,752 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 128)            │       123,648 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 247,686 (967.52 KB)
#  Trainable params: 247,686 (967.52 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from sklearn.metrics import f1_score
from tensorflow.keras.callbacks import Callback

class F1MacroCallback(Callback):
    def __init__(self, X_val, y_val, batch_size=256):
        super().__init__()
        self.X_val = X_val
        self.y_val = y_val
        self.bs = batch_size

    def on_epoch_end(self, epoch, logs=None):
        y_prob = self.model.predict(self.X_val, batch_size=self.bs, verbose=0)
        y_pred = y_prob.argmax(axis=1)
        y_true = self.y_val.argmax(axis=1)
        f1m = f1_score(y_true, y_pred, average='macro')
        logs = logs or {}
        logs['val_f1_macro'] = f1m
        print(f"\nval_f1_macro: {f1m:.4f}")

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

f1_cb = F1MacroCallback(X_val_scaled, y_val_one_hot, batch_size=256)

callbacks = [
    f1_cb,
    EarlyStopping(monitor='val_f1_macro', mode='max', patience=12, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_f1_macro', mode='max', factor=0.5, patience=5, min_lr=1e-5, verbose=1),
    # ModelCheckpoint('best_simple_cnn_f1.keras', monitor='val_f1_macro', mode='max', save_best_only=True, verbose=1)
]

# %%
model_history = gru.fit(
    X_train_scaled, y_train_one_hot,
    validation_data=(X_val_scaled, y_val_one_hot),
    epochs=30,
    batch_size=128,
    callbacks=callbacks + [f1_cb],
)
# Out:
# Epoch 1/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.4395 - loss: 1.4170
# val_f1_macro: 0.7215
#
# val_f1_macro: 0.7215
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 21s 148ms/step - accuracy: 0.4421 - loss: 1.4125 - val_accuracy: 0.7390 - val_loss: 0.8149 - val_f1_macro: 0.7215 - learning_rate: 0.0010
# Epoch 2/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7758 - loss: 0.7587
# val_f1_macro: 0.9161
#
# val_f1_macro: 0.9161
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.7767 - loss: 0.7571 - val_accuracy: 0.9171 - val_loss: 0.4797 - val_f1_macro: 0.9161 - learning_rate: 0.0010
# Epoch 3/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9182 - loss: 0.4850
# val_f1_macro: 0.9234
#
# val_f1_macro: 0.9234
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9186 - loss: 0.4838 - val_accuracy: 0.9225 - val_loss: 0.4201 - val_f1_macro: 0.9234 - learning_rate: 0.0010
# Epoch 4/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9372 - loss: 0.4213
# val_f1_macro: 0.9327
#
# val_f1_macro: 0.9327
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9371 - loss: 0.4215 - val_accuracy: 0.9307 - val_loss: 0.3900 - val_f1_macro: 0.9327 - learning_rate: 0.0010
# Epoch 5/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9492 - loss: 0.4001
# val_f1_macro: 0.9519
#
# val_f1_macro: 0.9519
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9492 - loss: 0.3999 - val_accuracy: 0.9497 - val_loss: 0.3662 - val_f1_macro: 0.9519 - learning_rate: 0.0010
# Epoch 6/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9587 - loss: 0.3736
# val_f1_macro: 0.9499
#
# val_f1_macro: 0.9499
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9584 - loss: 0.3741 - val_accuracy: 0.9470 - val_loss: 0.3665 - val_f1_macro: 0.9499 - learning_rate: 0.0010
# Epoch 7/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9550 - loss: 0.3798
# val_f1_macro: 0.9504
#
# val_f1_macro: 0.9504
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9549 - loss: 0.3798 - val_accuracy: 0.9477 - val_loss: 0.3571 - val_f1_macro: 0.9504 - learning_rate: 0.0010
# Epoch 8/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9524 - loss: 0.3680
# val_f1_macro: 0.9516
#
# val_f1_macro: 0.9516
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9525 - loss: 0.3679 - val_accuracy: 0.9490 - val_loss: 0.3593 - val_f1_macro: 0.9516 - learning_rate: 0.0010
# Epoch 9/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9522 - loss: 0.3647
# val_f1_macro: 0.9515
#
# val_f1_macro: 0.9515
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9523 - loss: 0.3647 - val_accuracy: 0.9490 - val_loss: 0.3650 - val_f1_macro: 0.9515 - learning_rate: 0.0010
# Epoch 10/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9521 - loss: 0.3717
# val_f1_macro: 0.9369
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# val_f1_macro: 0.9369
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9522 - loss: 0.3714 - val_accuracy: 0.9347 - val_loss: 0.3768 - val_f1_macro: 0.9369 - learning_rate: 0.0010
# Epoch 11/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9533 - loss: 0.3671
# val_f1_macro: 0.9522
#
# val_f1_macro: 0.9522
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9534 - loss: 0.3668 - val_accuracy: 0.9490 - val_loss: 0.3409 - val_f1_macro: 0.9522 - learning_rate: 5.0000e-04
# Epoch 12/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9572 - loss: 0.3522
# val_f1_macro: 0.9516
#
# val_f1_macro: 0.9516
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9571 - loss: 0.3523 - val_accuracy: 0.9483 - val_loss: 0.3458 - val_f1_macro: 0.9516 - learning_rate: 5.0000e-04
# Epoch 13/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9538 - loss: 0.3561
# val_f1_macro: 0.9555
#
# val_f1_macro: 0.9555
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9538 - loss: 0.3560 - val_accuracy: 0.9524 - val_loss: 0.3429 - val_f1_macro: 0.9555 - learning_rate: 5.0000e-04
# Epoch 14/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9543 - loss: 0.3554
# val_f1_macro: 0.9549
#
# val_f1_macro: 0.9549
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9544 - loss: 0.3552 - val_accuracy: 0.9517 - val_loss: 0.3447 - val_f1_macro: 0.9549 - learning_rate: 5.0000e-04
# Epoch 15/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9644 - loss: 0.3408
# val_f1_macro: 0.9541
#
# val_f1_macro: 0.9541
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9641 - loss: 0.3412 - val_accuracy: 0.9511 - val_loss: 0.3434 - val_f1_macro: 0.9541 - learning_rate: 5.0000e-04
# Epoch 16/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9579 - loss: 0.3509
# val_f1_macro: 0.9528
#
# val_f1_macro: 0.9528
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9580 - loss: 0.3510 - val_accuracy: 0.9497 - val_loss: 0.3493 - val_f1_macro: 0.9528 - learning_rate: 5.0000e-04
# Epoch 17/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9592 - loss: 0.3492
# val_f1_macro: 0.9560
#
# val_f1_macro: 0.9560
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9592 - loss: 0.3492 - val_accuracy: 0.9531 - val_loss: 0.3455 - val_f1_macro: 0.9560 - learning_rate: 5.0000e-04
# Epoch 18/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9645 - loss: 0.3448
# val_f1_macro: 0.9560
#
# val_f1_macro: 0.9560
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9643 - loss: 0.3451 - val_accuracy: 0.9531 - val_loss: 0.3474 - val_f1_macro: 0.9560 - learning_rate: 5.0000e-04
# Epoch 19/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9632 - loss: 0.3506
# val_f1_macro: 0.9540
#
# val_f1_macro: 0.9540
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9631 - loss: 0.3506 - val_accuracy: 0.9511 - val_loss: 0.3431 - val_f1_macro: 0.9540 - learning_rate: 5.0000e-04
# Epoch 20/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9586 - loss: 0.3441
# val_f1_macro: 0.9522
#
# val_f1_macro: 0.9522
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9586 - loss: 0.3442 - val_accuracy: 0.9490 - val_loss: 0.3422 - val_f1_macro: 0.9522 - learning_rate: 5.0000e-04
# Epoch 21/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9576 - loss: 0.3461
# val_f1_macro: 0.9508
#
# val_f1_macro: 0.9508
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.9577 - loss: 0.3462 - val_accuracy: 0.9477 - val_loss: 0.3454 - val_f1_macro: 0.9508 - learning_rate: 5.0000e-04
# Epoch 22/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9600 - loss: 0.3496
# val_f1_macro: 0.9566
#
# val_f1_macro: 0.9566
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9601 - loss: 0.3494 - val_accuracy: 0.9538 - val_loss: 0.3430 - val_f1_macro: 0.9566 - learning_rate: 5.0000e-04
# Epoch 23/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9594 - loss: 0.3467
# val_f1_macro: 0.9540
#
# val_f1_macro: 0.9540
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9595 - loss: 0.3466 - val_accuracy: 0.9511 - val_loss: 0.3437 - val_f1_macro: 0.9540 - learning_rate: 5.0000e-04
# Epoch 24/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9650 - loss: 0.3423
# val_f1_macro: 0.9554
#
# val_f1_macro: 0.9554
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9649 - loss: 0.3424 - val_accuracy: 0.9524 - val_loss: 0.3388 - val_f1_macro: 0.9554 - learning_rate: 5.0000e-04
# Epoch 25/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9639 - loss: 0.3390
# val_f1_macro: 0.9560
#
# val_f1_macro: 0.9560
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9638 - loss: 0.3391 - val_accuracy: 0.9531 - val_loss: 0.3438 - val_f1_macro: 0.9560 - learning_rate: 5.0000e-04
# Epoch 26/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9642 - loss: 0.3366
# val_f1_macro: 0.9559
#
# val_f1_macro: 0.9559
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9640 - loss: 0.3368 - val_accuracy: 0.9531 - val_loss: 0.3407 - val_f1_macro: 0.9559 - learning_rate: 5.0000e-04
# Epoch 27/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9643 - loss: 0.3405
# val_f1_macro: 0.9528
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# val_f1_macro: 0.9528
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9643 - loss: 0.3405 - val_accuracy: 0.9497 - val_loss: 0.3415 - val_f1_macro: 0.9528 - learning_rate: 5.0000e-04
# Epoch 28/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9598 - loss: 0.3408
# val_f1_macro: 0.9560
#
# val_f1_macro: 0.9560
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9598 - loss: 0.3406 - val_accuracy: 0.9531 - val_loss: 0.3378 - val_f1_macro: 0.9560 - learning_rate: 2.5000e-04
# Epoch 29/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9633 - loss: 0.3335
# val_f1_macro: 0.9554
#
# val_f1_macro: 0.9554
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9633 - loss: 0.3337 - val_accuracy: 0.9524 - val_loss: 0.3418 - val_f1_macro: 0.9554 - learning_rate: 2.5000e-04
# Epoch 30/30
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9561 - loss: 0.3456
# val_f1_macro: 0.9566
#
# val_f1_macro: 0.9566
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9564 - loss: 0.3452 - val_accuracy: 0.9538 - val_loss: 0.3414 - val_f1_macro: 0.9566 - learning_rate: 2.5000e-04

# %%
import matplotlib.pyplot as plt
import seaborn as sns

loss =model_history.history['loss']
val_loss =model_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc =model_history.history['accuracy']
val_acc =model_history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, f1_score, classification_report
import numpy as np

# 예측
y_val_prob = gru.predict(X_val_scaled, batch_size=256)
y_val_pred = y_val_prob.argmax(axis=1)
y_val_true = y_val_one_hot.argmax(axis=1)

# 혼동행렬
cm = confusion_matrix(y_val_true, y_val_pred)
f1_macro = f1_score(y_val_true, y_val_pred, average='macro')
f1_micro = f1_score(y_val_true, y_val_pred, average='micro')

# 결과 출력
print(f"Validation macro F1: {f1_macro:.4f}")
print(f"Validation micro F1: {f1_micro:.4f}")
print(classification_report(y_val_true, y_val_pred))

# -----------------------------
# 🔥 히트맵 시각화
# -----------------------------
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=True,
            xticklabels=np.unique(y_val_true),
            yticklabels=np.unique(y_val_true))
plt.title(f'Confusion Matrix (F1_macro={f1_macro:.3f})')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Validation macro F1: 0.9566
# Validation micro F1: 0.9538
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       243
#            1       1.00      1.00      1.00       203
#            2       1.00      1.00      1.00       207
#            3       0.85      0.88      0.87       246
#            4       0.90      0.86      0.88       281
#            5       1.00      1.00      1.00       291
#
#     accuracy                           0.95      1471
#    macro avg       0.96      0.96      0.96      1471
# weighted avg       0.95      0.95      0.95      1471
